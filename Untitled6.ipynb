# %%
import pandas as pd
df=pd.read_csv("C:/Users/Francisco/OneDrive/Dokumen/Data.csv")

# %%
df
# Out:
#                        nama lengkap       gender  angkatan  tinggi badan  \
# 0                              Dave  laki - laki      2023           165
# 1                         Francisco  laki - laki      2023           170
# 2               Faiz Abyan Heryanto  laki - laki      2023           165
# 3                           Michael  laki - laki      2023           167
# 4        partahi daniel tua limbong  laki - laki      2023           173
# 5                   hafidz ramadhan  laki - laki      2023           169
# 6                         Francisco  laki - laki      2023           170
# 7            Muhammad Rayyan Naufal  laki - laki      2023           171
# 8                  Yustianas Rombon  laki - laki      2023           173
# 9             Zahwa Nur Azkia Putri    perempuan      2023           154
# 10                         Dave F.M  laki - laki      2023           168
# 11                  Calista Azzahra    perempuan      2023           160
# ...

# %%
df.describe()
# Out:
#        angkatan  tinggi badan  waktu perjalanan / menit
# count      33.0     33.000000                 33.000000
# mean     2023.0    168.484848                 45.757576
# std         0.0      6.847085                 29.349223
# min      2023.0    152.000000                 10.000000
# 25%      2023.0    165.000000                 30.000000
# 50%      2023.0    170.000000                 45.000000
# 75%      2023.0    172.000000                 60.000000
# max      2023.0    185.000000                150.000000
